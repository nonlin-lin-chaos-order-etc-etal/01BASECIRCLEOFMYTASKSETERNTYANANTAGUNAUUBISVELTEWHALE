# %% [markdown]
# <a href="https://colab.research.google.com/github/ANANTASHESHALOKAGREENTARAEGPTRANSHOLON/01BASECIRCLEOFMYTASKSETERNTYANANTAGUNAUUBISVELTEWHALE/blob/main/%F0%9F%92%9A_%F0%9F%92%8E_%E2%9B%93_KDZDAO_%D0%9A%D0%9E%D0%9C%D0%9D%D0%90%D0%A2%D0%90_%D0%94%D0%9B%D0%AF_%D0%97%D0%90%D0%9D%D0%AF%D0%A2%D0%98%D0%99_Data_Table_Display_%E2%85%80%C2%B1%E2%88%9E_T%F0%9F%8C%8C%C2%A4%F0%9F%92%8E%F0%9F%8C%88%F0%9F%8C%8A%F0%9F%92%9B%E2%9B%B0%F0%9F%8F%A6%E2%9D%A4%F0%9F%8C%85%F0%9F%91%8D%F0%9F%92%AF%F0%9F%99%8F%F0%9F%92%B0%F0%9F%9A%80%F0%9F%A4%A9%E2%9C%A8%F0%9F%A5%91%F0%9F%92%96%F0%9F%90%B8%F0%9F%92%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Table Display
#
# Colab includes an extension that renders pandas dataframes into interactive displays that can be filtered, sorted, and explored dynamically.
#
# Data table display for Pandas dataframes can be enabled by running:
# ```python
# from google.colab import data_table
# data_table.enable_dataframe_formatter()
# ```
# and disabled by running
# ```python
# from google.colab import data_table
# data_table.disable_dataframe_formatter()
# ```

# %% [markdown]
# ## Exploring Data Tables
#
# Here is an example of a data table display:

# %%
from google.colab import data_table
import pandas as pd
# from vega_datasets import data

# !whoami
# %cd /content/
# !rm -rf vcs
# !mkdir -pv vcs
# %cd /content/vcs/
# !echo "pwd: `pwd`"
# !git clone https://github.com/KDZDAO/KDZDAO.git KDZ
# %cd /content/vcs/KDZ
# !git remote -v
# !git pull
# !git status
# !git branch
# !git log -n 3

data_table.enable_dataframe_formatter()

df = pd.read_csv("KDZDAO.tmpid1.csv")
df

# data.airports()
# Out:
# root
# /content
# mkdir: created directory 'vcs'
# /content/vcs
# pwd: /content/vcs
# Cloning into 'KDZ'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 45 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), done.
# /content/vcs/KDZ
# origin	https://github.com/KDZDAO/KDZDAO.git (fetch)
# origin	https://github.com/KDZDAO/KDZDAO.git (push)
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# * main
# commit e259d13a96094897d94276641f8b4e78468f34a9 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 88be294 2a54ea1
# Author: nonlin-lin-chaos-order-etc-etal <19966907+nonlin-lin-chaos-order-etc-etal@users.noreply.github.com>
# Date:   Sat Jan 15 16:00:49 2022 +0800
#
#     Merge pull request #2 from ANANTASHESHALOKAGREENTARAEGPTRANSHOLON/patch-2
#
# ...

# %% [markdown]
# ## Links
#
#  * https://github.com/KDZDAO/KDZDAO (only the csv & transactions bookkeeping file as of moment of writing)
#  * http://t.me/KDZDAOBOT (not implemented as of moment of writing)
#
# ## Rumours
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [13.01.2022 20:48]
#
# Кст Саш я похоже нашёл прекраснейшее решение для всех этих моих мириад проектов
#
# Игра в бисер
#
# ```
# <fj> а валютой сделать бисерины
# <fj> игра в бисер
# <fj> у меня даж домен по игре в бисер занят на нау сш
# <fj> !price beads
# <LibreLifeBot> Error: 'data'
# ```
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*,[13.01.2022 20:49]
#
# так что их нада тебе будет отсыпать
#
# и Митхуну который тоже ради интересу 300 руб дал
#
# > AKA Arraki, [14.01.2022 01:58]
#
# Бисер на каком бч?
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 01:58]
#
# всюду
#
# всех сортов и оттенков
#
# > AKA Arraki, [14.01.2022 01:59]
#
# Ну блин, ты пока только в чатах отсыпаешь, даже не в гугл таблице как USSR
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 01:59]
#
# ну охота получше сварить
#
# > AKA Arraki, [14.01.2022 01:59]
#
# [ 🎄 Sticker ]
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 01:59]
#
# стекляшки-то
#
# > AKA Arraki, [14.01.2022 02:00]
#
# Это мы, твои фэны, ждем токенов
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 02:00]
#
# а давай и в гугл таблице отсыплю
#
# норм для начала
#
# > AKA Arraki, [14.01.2022 02:00]
#
# [ 😨 Sticker ]
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 02:01]
#
# [Forwarded from TON Degen Club News (SCAM)]
#
# Если вы думали что TON Degen Club ( https://t.me/tondegen )
# это самое абсурдное что происходило в тон комьюнити,
# то скорей всего вы здесь совсем недавно, либо слишком поверхностно
#
# Для меня одним из самых абсурдных проектов являлся и является USSR
# ( https://t.me/USSRGoUp ) о котором я узнал еще в конце ноября,
# где парень решил выпустить свои USSR токены в гугл таблице.
# Нет. Вы не ослышались. Этот парень выбрал эмиссию, назначал цену
# и начал продавать токены, баланс которых на протяжении месяца
# висел сперва в файле, а потом в гугл таблице.
#
# Таким образом он распродал несколько миллионов своих гугл токенов :D,
# а несколько дней назад решил назначить им новую цену, перейдя на фазу
# развития один точка ноль. Вдумайтесь еще раз. Парень создал таблицу,
# продает в ней числа и назначает им курс.
#
# В него поверили люди и он начал эволюционировать, сперва сделал
# логотип, потом стикеры, нарисовал какую-то нфт коллекцию
# ( https://t.me/ton_bears_nft ) и вот сейчас запустил своего
# бота ( https://t.me/ussr_market_bot ) на уровне TON Diamonds
# (лол) в отличии от всех нас с криптоботом, через которого
# продает токены и нфт.
#
# Я не призываю вас в этом участвовать, но хочу чтобы вы начали
# выкупать весь тот абсурд что происходит и были в тренде. Мне
# очень смешно и я хочу чтобы вам было тоже.
#
# https://t.me/tondegen
#
#  * `<skomorox>` Magister_Ludi: это кончится тем, что мне придется, ↯ боевой операцией, ↯ освобождать тебя, где тебя заведомо убьют
#  * `<skomorox>` Magister_Ludi: но, .. не просто так))
#  * `<Magister_Ludi>` ну не надо, чтобы так кончалось
#  * `<skomorox>` Magister_Ludi: ты идешь к этому, ↠ прямым шагом, ↠ несмотря на все мои советы
#
# > Eugene Alt Григория сын Philippow Markandeya 𒀭𒄑𒉋𒂵𒈨𒌋𒌋𒌋 🐡 SHARDAHC45*, [14.01.2022 04:18]
#
# 1001 бусинка за 1 цент как символ жизни, что ли
#
# воопще конечно надо сделать pos
#
# а можна продавать не бусинки а прост землю. тож как символ жизни
#
# ```
# <Magister_Ludi> !price LIVELY
# <LibreLifeBot> Error: 'data'
# <Magister_Ludi> !price LIFE
# <LibreLifeBot> LIFE/USD: 0.00
# <Magister_Ludi> !price HAPPY
# <LibreLifeBot> HAPPY/USD: 0.00
# <Magister_Ludi> !price LIVES
# <LibreLifeBot> Error: 'data'
# <Magister_Ludi> !price ZANAC
# <LibreLifeBot> Error: 'data'
# <Magister_Ludi> !price KEEPER
# <LibreLifeBot> Error: 'data'
# ```
#
# * Now talking on #ru
#
# * Topic for #ru is: Русскоязычный канал | 333.i2p || kislitsa.i2p || pubsub.i2p || reg.i2p || privatebin.i2p || поисковик: legwork.i2p
#
# * Topic for #ru set by R4SAS!r4sas@r4sas.i2p (Sun Dec 26 09:21:38 2021)
#
# * KATAKOMBYNNNNBOT1 has quit (Ping timeout: 120 seconds)
#
# * KATAKOMBYNNNNBOT1 (KATAKOMBYN@Clk-A07718C.b32.i2p) has joined
#
# ```
# <AVATARJFVULGARDISPLAYOFPOWER> гавна
# <AVATARJFVULGARDISPLAYOFPOWER> абалденый фреймворк "пивоварня"
# <AVATARJFVULGARDISPLAYOFPOWER> !price lif
# <LibreLifeBot> LIF/USD: 0.09
# <AVATARJFVULGARDISPLAYOFPOWER> !price libre
# <LibreLifeBot> LIBRE/USD: 0.07
# <AVATARJFVULGARDISPLAYOFPOWER> !price inflif
# <LibreLifeBot> Error: 'data'
# <AVATARJFVULGARDISPLAYOFPOWER> !price equil
# <LibreLifeBot> Error: 'data'
# <AVATARJFVULGARDISPLAYOFPOWER> !price one
# <LibreLifeBot> ONE/USD: 0.35
# <AVATARJFVULGARDISPLAYOFPOWER> !price harmon
# <LibreLifeBot> Error: 'data'
# <AVATARJFVULGARDISPLAYOFPOWER> !price harmony
# <LibreLifeBot> Error: 'data'
# <skomorox> Гавна
# <AVATARJFVULGARDISPLAYOFPOWER> !price middle
# <LibreLifeBot> Error: 'data'
# <AVATARJFVULGARDISPLAYOFPOWER> !price stalin
# <LibreLifeBot> Error: 'data'
# <AVATARJFVULGARDISPLAYOFPOWER> !price tiho spokoino
# <LibreLifeBot> Error: 'data'
# * val has quit (Ping timeout: 120 seconds)
# <AVATARJFVULGARDISPLAYOFPOWER> !price itoopi
# <LibreLifeBot> Error: 'data'
# ```
#
# `<skomorox>` AVATARJFVULGARDISPLAYOFPOWER: ну что данила мастер, не выходит твой каменный цветок?))
#
#
# ```
# <AVATARJFVULGARDISPLAYOFPOWER> skomorox, дохрена выходит
# <AVATARJFVULGARDISPLAYOFPOWER> ща ща всё попрёт в рост
# * val (val@*.b32.i2p) has joined
# <AVATARJFVULGARDISPLAYOFPOWER> skomorox, прост продаю бесконечную жизнь и покупаю itoopi
#
# ...
#
#
# <skomorox> AVATARJFVULGARDISPLAYOFPOWER:бесконечная жизнь это адская хуита пиздец
# <skomorox> как блять, ты это измыслил??
# <AVATARJFVULGARDISPLAYOFPOWER> много как
# <AVATARJFVULGARDISPLAYOFPOWER> ток срединный путь круче
# <AVATARJFVULGARDISPLAYOFPOWER> вот сталин срединным шёл
# <AVATARJFVULGARDISPLAYOFPOWER> он гитлеровцев убил
# <AVATARJFVULGARDISPLAYOFPOWER> а больше никого не тронул
# <AVATARJFVULGARDISPLAYOFPOWER> гитлер прост превысил лимит терпения
# <skomorox> Дедушка гитлер был очегь добрый
# <skomorox> он обожал, цвеьы и детей
# <skomorox> он в бой посылал железные орды
# <skomorox> для сохраненья породы людей
# <skomorox> ---
# <AVATARJFVULGARDISPLAYOFPOWER> skomorox, я сёдня измыслил что у
# меня поведение это хаотический взрыв беспрестанный
# <skomorox> Типа
# <skomorox> того
# <skomorox> бурление
# <AVATARJFVULGARDISPLAYOFPOWER> и я иногда стал обрубать места просёра энергии
# <AVATARJFVULGARDISPLAYOFPOWER> скажем отрубил в боте добавление цитат
# * uis has quit (Ping timeout: 120 seconds)
# <AVATARJFVULGARDISPLAYOFPOWER> или чаты стал чаще закрывать разные
# <AVATARJFVULGARDISPLAYOFPOWER> вообще мож скоро умру
# <AVATARJFVULGARDISPLAYOFPOWER> чёт с кровью
# <AVATARJFVULGARDISPLAYOFPOWER> skomorox, эт скорее про бесконечную жизнь биосферы
# * uis (uis@*.b32.i2p) has joined
# <AVATARJFVULGARDISPLAYOFPOWER> в её плотном или тонком выражении
# <skomorox> Так она и так безсмертна
# <AVATARJFVULGARDISPLAYOFPOWER> во во во
# <skomorox> Коли, умрешь- приходи, ток, слишклм не кипишуй) проводим, куды надо
# <AVATARJFVULGARDISPLAYOFPOWER> чо бы напечатать
# <AVATARJFVULGARDISPLAYOFPOWER> какое слов до 6 букв включительно
# <AVATARJFVULGARDISPLAYOFPOWER> чтоб за него баблом голосовали и стейкали
# <AVATARJFVULGARDISPLAYOFPOWER> чтобы все не****** обеими руками за
# <AVATARJFVULGARDISPLAYOFPOWER> прост можт babies
# <AVATARJFVULGARDISPLAYOFPOWER> kids
# * astraldev (astraldev_@*.b32.i2p) has joined
# <AVATARJFVULGARDISPLAYOFPOWER> не хочу такую таску. сливаюсь нахой
# <AVATARJFVULGARDISPLAYOFPOWER> !price kdz
# <LibreLifeBot> Error: 'data'
#
#
# ```

# %% [markdown]
# A few interesting features of the data table display:
#
# - Clicking the <button>Filter</button> button in the upper right allows you to search for terms or values in any particular column.
# - Clicking on any column title lets you sort the results according to that column's value.
# - The table displays only a subset of the data at a time. You can navigate through pages of data using the controls on the lower right.

# %% [markdown]
# ## Disabling Data Table Display
#
# To restore the native pandas dataframe display, use the following:

# %%
from google.colab import data_table
data_table.disable_dataframe_formatter()

data.airports()
# Out:
#      iata                       name  ...   latitude   longitude
# 0     00M                    Thigpen  ...  31.953765  -89.234505
# 1     00R       Livingston Municipal  ...  30.685861  -95.017928
# 2     00V                Meadow Lake  ...  38.945749 -104.569893
# 3     01G               Perry-Warsaw  ...  42.741347  -78.052081
# 4     01J           Hilliard Airpark  ...  30.688012  -81.905944
# ...   ...                        ...  ...        ...         ...
# 3371  ZEF            Elkin Municipal  ...  36.280024  -80.786069
# 3372  ZER  Schuylkill Cty/Joe Zerbey  ...  40.706449  -76.373147
# 3373  ZPH      Zephyrhills Municipal  ...  28.228065  -82.155916
# 3374  ZUN                 Black Rock  ...  35.083227 -108.791777
# 3375  ZZV       Zanesville Municipal  ...  39.944458  -81.892105
#
# [3376 rows x 7 columns]

# %% [markdown]
# ## Customizing the Data Table Display

# %% [markdown]
# If you would like to create data tables directly, you can do that with the Python API, which allows additional customizations via keyword arguments:

# %%
from google.colab import data_table
data_table.DataTable(data.airports(), include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iata</th>
#       <th>name</th>
#       <th>city</th>
#       <th>state</th>
#       <th>country</th>
#       <th>latitude</th>
#       <th>longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>00M</td>
#       <td>Thigpen</td>
#       <td>Bay Springs</td>
#       <td>MS</td>
#       <td>USA</td>
#       <td>31.953765</td>
#       <td>-89.234505</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00R</td>
#       <td>Livingston Municipal</td>
#       <td>Livingston</td>
#       <td>TX</td>
#       <td>USA</td>
#       <td>30.685861</td>
#       <td>-95.017928</td>
# ...
